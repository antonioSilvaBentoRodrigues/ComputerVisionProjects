# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
cd /content/gdrive/MyDrive/Projects/FootballPlayers
# Out:
# /content/gdrive/MyDrive/Projects/FootballPlayers

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 20.5MB/s]

# %%
results = model.train(data='/content/gdrive/MyDrive/Projects/FootballPlayers/football-players-detection-10/data.yaml',
                      epochs=100)
# Out:
# Ultralytics YOLOv8.2.69 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
