# %%
pip install ultralytics

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
cd /content/gdrive/MyDrive/Projects/FootballPlayers
# Out:
# /content/gdrive/MyDrive/Projects/FootballPlayers

# %%
model = YOLO('/content/gdrive/MyDrive/Projects/FootballPlayers/runs/detect/train/weights/best.pt')

# %%
BBOX_COLORS = np.random.randint(0, 255,(len(model.names),3), dtype='int64')

# %%
video_path = '/content/gdrive/MyDrive/Projects/FootballPlayers/match_sample.mp4'
thresh=0.5
out_path = f'{video_path}_output.mp4'
video_cap = cv2.VideoCapture(video_path)
ret, frame = video_cap.read()
H, W ,_ = frame.shape
output = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc(*'MP4V'), int(video_cap.get(cv2.CAP_PROP_FPS)),(W,H))
while ret:
  results = model.track(frame, stream=True)
  for detection in results:
    classes_names = detection.names
    for bbox in detection.boxes:
      if bbox.conf[0] > thresh:
        [x1,y1,x2,y2] = bbox.xyxy[0]
        x1,y1,x2,y2 = int(x1), int(y1), int(x2), int(y2)
        class_ = int(bbox.cls[0])
        class_name = classes_names[class_]
        color = (int(BBOX_COLORS[class_][0]),int(BBOX_COLORS[class_][1]),int(BBOX_COLORS[class_][2]))
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 1)
        cv2.putText(frame, f'{classes_names[int(class_)]} {bbox.conf[0]*100:.2f}%',
                    (x1,y1), cv2.FONT_HERSHEY_SIMPLEX,1,color,1)
  output.write(frame)
  ret, frame=video_cap.read()
video_cap.release()
output.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 goalkeeper, 17 players, 2 referees, 43.0ms
# Speed: 3.2ms preprocess, 43.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 2 referees, 14.3ms
# Speed: 6.3ms preprocess, 14.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 3 referees, 33.0ms
# Speed: 18.5ms preprocess, 33.0ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 36.4ms
# Speed: 9.4ms preprocess, 36.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 25.9ms
# Speed: 3.3ms preprocess, 25.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
