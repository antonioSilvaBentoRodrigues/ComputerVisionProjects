# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/MyDrive/FaceDetection
# Out:
# /content/gdrive/MyDrive/FaceDetection

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='/content/gdrive/MyDrive/FaceDetection/Face-Detection-24/data.yaml',
                      batch=32,
                      epochs=50)
# Out:
# Ultralytics YOLOv8.2.73 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
